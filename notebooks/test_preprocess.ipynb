# %%
import pandas as pd
from cleaning.preprocess import getMissingValuesContainingColsWithCountOrMsg
from cleaning.preprocess import handleMissingValues
from cleaning.preprocess import getNumberOfDuplicateRows
from cleaning.preprocess import removeDuplicateRows
from cleaning.preprocess import getNumericColumnNamesFromData
from cleaning.preprocess import getTableOfNumericalAndCategoricalColumnsInDataOrMsg
from cleaning.preprocess import getCategoricalColumnNamesFromData
from cleaning.utils import preprocessGetDuplicateRowsCountMessageIfAny
from cleaning.preprocess import applyScalingOnNumericalColumns
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.figure_factory as ff

# %%
titanic = pd.read_csv("datasets\\raw\\titanic.csv")
iris = pd.read_csv("datasets\\raw\\iris.csv")
onlineRetail = pd.read_csv("datasets\\raw\\online_retail.csv", encoding = "latin")

# %%
titanic.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
getMissingValuesContainingColsWithCountOrMsg(titanic)
# Out:
#   Column Name  Missing Count
# 0         Age            177
# 1       Cabin            687
# 2    Embarked              2

# %%
getMissingValuesContainingColsWithCountOrMsg(iris)

# %%
# handleMissingValues(titanic,{"Age" : "Drop Column"})

# %%
getMissingValuesContainingColsWithCountOrMsg(titanic)
# Out:
#   Column Name  Missing Count
# 0         Age            177
# 1       Cabin            687
# 2    Embarked              2

# %%
titanic['Cabin'] = titanic['Cabin'].fillna(titanic['Cabin'].mode()[0])

# %%
getMissingValuesContainingColsWithCountOrMsg(titanic)
# Out:
#   Column Name  Missing Count
# 0         Age            177
# 1    Embarked              2

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin            0
# Embarked         2
# dtype: int64

# %%
getNumberOfDuplicateRows(onlineRetail)
# Out:
# np.int64(5268)

# %%
removeDuplicateRows(onlineRetail)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
getNumberOfDuplicateRows(onlineRetail)
# Out:
# np.int64(0)

# %%
titanic.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare    Cabin Embarked
# 0      0  A/5 21171  7.25  B96 B98        S

# %%
titanic.select_dtypes(include=['number']).columns.to_list()
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
titanic.select_dtypes(include=['object']).columns.to_list()
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %%
getNumericColumnNamesFromData(titanic)
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
iris.head(1)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa

# %%
getNumericColumnNamesFromData(iris)
# Out:
# ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

# %%
titanic.select_dtypes(include=['object']).columns.to_list()
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %%
getCategoricalColumnNamesFromData(titanic)
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_without_categorical_col = iris.iloc[:, :-1]

# %%
iris_without_categorical_col
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
if(len(getCategoricalColumnNamesFromData(iris_without_categorical_col)) == 0): print('No Categorical Columns in Data!')
# Out:
# No Categorical Columns in Data!

# %%
getTableOfNumericalAndCategoricalColumnsInDataOrMsg(titanic)
# Out:
#   Numerical Column Names Categorical Column Names
# 0            PassengerId                     Name
# 1                    Age                      Sex
# 2                  SibSp                   Ticket
# 3                  Parch                    Cabin
# 4                   Fare                 Embarked
# 5                    NaN                 Survived
# 6                    NaN                   Pclass

# %%
titanic['Pclass'].nunique()
# Out:
# 3

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked
# 0      0         A/5 21171   7.2500  B96 B98        S
# 1      0          PC 17599  71.2833      C85        C
# 2      0  STON/O2. 3101282   7.9250  B96 B98        S
# 3      0            113803  53.1000     C123        S
# ...

# %%
titanic['Fare'].head()
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# Name: Fare, dtype: float64

# %%
titanic[['Fare']].head()
# Out:
#       Fare
# 0   7.2500
# 1  71.2833
# 2   7.9250
# 3  53.1000
# 4   8.0500

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin            0
# Embarked         2
# dtype: int64

# %%
titanic.sample(5)
# Out:
#      PassengerId  Survived  Pclass                      Name     Sex   Age  \
# 288          289         1       2      Hosono, Mr. Masabumi    male  42.0
# 318          319         1       1  Wick, Miss. Mary Natalie  female  31.0
# 487          488         0       1   Kent, Mr. Edward Austin    male  58.0
# 160          161         0       3  Cribb, Mr. John Hatfield    male  44.0
# 216          217         1       3    Honkanen, Miss. Eliina  female  27.0
#
#      SibSp  Parch            Ticket      Fare    Cabin Embarked
# 288      0      0            237798   13.0000  B96 B98        S
# 318      0      2             36928  164.8667       C7        S
# 487      0      0             11771   29.7000      B37        C
# 160      0      1            371362   16.1000  B96 B98        S
# 216      0      0  STON/O2. 3101283    7.9250  B96 B98        S
