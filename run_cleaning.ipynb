# %% [markdown]
# GET MISSING VALUES CONTAINING COLUMNS FROM DATA

# %%
from cleaning.preprocess import get_missing_values_containing_cols
import pandas as pd

# %%
df = pd.read_csv("datasets\\raw\\titanic.csv")
df.head()

# %%
get_missing_values_containing_cols(df)
